# %% [markdown]
# #ASSIGNMENT - FILES , EXCEPTION HANDLING ,

# %%
#THEORY QUESTION

# %% [markdown]
# Q1 - 1. What is the difference between interpreted and compiled languages?
#
# ANS - Interpreted languages execute code line by line using an interpreter, which makes debugging easier but slows execution. Compiled languages first convert the entire source code into machine code before execution, resulting in faster performance. Interpreted languages do not require a separate compilation step, while compiled languages need a compiler. Errors in interpreted languages are detected at runtime, whereas compiled languages detect errors during compilation. For example, Python is an interpreted language, while C is a compiled language.

# %% [markdown]
# Q2 - What is exception handling in Python?
#
# ANS- Exception handling in Python is a mechanism used to handle runtime errors and prevent program termination. It allows the programmer to detect errors and manage them gracefully using try and except blocks. This improves program reliability and user experience. Exception handling ensures that the remaining code executes even after an error occurs. For example, dividing a number by zero can be handled using a ZeroDivisionError exception.

# %% [markdown]
# Q3 - What is the purpose of the finally block in exception handling?
#
#
# ANS - The finally block in Python is used to execute code regardless of whether an exception occurs or not. It is mainly used for cleanup activities such as closing files or releasing resources. The code inside the finally block always runs after the try and except blocks. This ensures that important operations are not skipped. For example, a file opened in a program can be safely closed in the finally block.

# %% [markdown]
# Q4 - What is logging in Python?
#
#
# ANS - Logging in Python is the process of recording events, errors, and messages that occur during program execution. It helps developers track program flow and debug issues efficiently. Logging is more flexible and powerful than using print statements because it supports different severity levels. Logs can be saved to files for future reference. For example, the logging module can be used to record error messages.

# %% [markdown]
# Q5- What is the significance of the __del__ method in Python?
#
#
# ANS - The __del__ method in Python is a destructor that is automatically called when an object is destroyed. It is used to free resources such as memory or open files associated with the object. This method helps in proper cleanup of objects. The timing of its execution depends on Python’s garbage collection. For example, when an object goes out of scope, the __del__ method may be invoked.

# %% [markdown]
# Q6 - What is the difference between import and from ... import in Python?
#
#
# ANS  - The import statement imports the entire module and requires accessing functions or variables using the module name. In contrast, from ... import imports specific functions or variables directly into the namespace. Using import avoids name conflicts, while from ... import makes the code shorter and cleaner. However, excessive use of from ... import can reduce readability. For example, import math uses math.sqrt(), whereas from math import sqrt uses sqrt().

# %% [markdown]
# Q7 - How can you handle multiple exceptions in Python?
#
# ANS - Multiple exceptions in Python can be handled by using multiple except blocks or by specifying a tuple of exceptions in a single except block. This allows the program to respond differently to different error types. Handling multiple exceptions improves program robustness. It prevents the program from crashing unexpectedly. For example, both ValueError and ZeroDivisionError can be handled together

# %% [markdown]
# Q8 - What is the purpose of the with statement when handling files in Python?
#
# ANS - The with statement in Python is used to simplify file handling and ensure proper resource management. It automatically closes the file after the block is executed, even if an exception occurs. This prevents memory leaks and file corruption. The with statement improves code readability and safety. For example, opening a file using with open("file.txt") as f: ensures the file is closed automatically

# %% [markdown]
# Q9 - What is the difference between multithreading and multiprocessing?
#
# ANS - Multithreading involves multiple threads running within the same process and sharing memory. It is suitable for I/O-bound tasks and has faster context switching. Multiprocessing involves multiple processes with separate memory spaces, allowing true parallelism. It is best suited for CPU-bound tasks. For example, web servers use multithreading, while heavy computations use multiprocessing.

# %% [markdown]
# Q10 - What are the advantages of using logging in a program?
#
# ANS - Logging provides a systematic way to track program execution and errors. It helps in debugging and monitoring applications, especially in production environments. Logs can be stored permanently for analysis. Logging supports different severity levels, such as error and warning. For example, error logs can help identify issues after program execution.

# %% [markdown]
# Q11 - What is memory management in Python?
#
# ANS  - Memory management in Python refers to the process of allocating and deallocating memory for objects during program execution. Python automatically manages memory using a built-in memory manager. It uses garbage collection to free unused memory. This reduces the risk of memory leaks. For example, unused objects are automatically removed from memory.

# %% [markdown]
# Q12 - What are the basic steps involved in exception handling in Python?
#
# ANS - The basic steps of exception handling include placing risky code inside a try block and catching errors using an except block. If no exception occurs, the else block may execute. The finally block runs regardless of the outcome. These steps ensure controlled program execution. For example, file operations are often enclosed in these blocks.

# %% [markdown]
# Q13 - Why is memory management important in Python?
#
# ANS - Memory management is important in Python to ensure efficient use of system resources. It prevents memory leaks and improves program performance. Proper memory management ensures application stability. It allows large and complex programs to run smoothly. For example, clearing unused objects helps free memory.

# %% [markdown]
# Q14 - What is the role of try and except in exception handling?
#
# ANS - The try block contains code that may cause an error, while the except block handles the error. This mechanism prevents abrupt program termination. It allows developers to manage errors gracefully. Using try and except improves code reliability. For example, invalid user input can be handled safely.

# %% [markdown]
# Q15 - How does Python’s garbage collection system work?
#
#
# ANS - Python’s garbage collection system primarily uses reference counting to track objects. When an object’s reference count becomes zero, it is removed from memory. Python also detects and cleans circular references. Garbage collection runs automatically in the background. For example, unused objects are deleted without user intervention.

# %% [markdown]
# Q16 - What is the purpose of the else block in exception handling?
#
# ANS - The else block in exception handling executes only when no exception occurs in the try block. It helps separate normal execution code from error-handling code. This improves program clarity and structure. The else block is optional. For example, a success message can be printed in the else block.

# %% [markdown]
# Q17 - What are the common logging levels in Python?
#
# ANS - Python provides several logging levels such as DEBUG, INFO, WARNING, ERROR, and CRITICAL. These levels indicate the severity of log messages. They help filter important information. Logging levels improve monitoring and debugging. For example, ERROR level logs serious issues.

# %% [markdown]
# Q18 - . What is the difference between os.fork() and multiprocessing in Python?
#
# ANS - os.fork() is a low-level system call available on Unix-based systems to create a child process. It duplicates the current process. The multiprocessing module is a high-level, cross-platform solution for creating processes. It is easier and safer to use. For example, multiprocessing works on both Windows and Linux.

# %% [markdown]
# Q19 - What is the importance of closing a file in Python?
#
# ANS -Closing a file in Python releases system resources and ensures data is properly saved. It prevents file corruption and data loss. Open files consume memory and file descriptors. Proper file closure improves program reliability. For example, using file.close() ensures data is written to disk.

# %% [markdown]
# Q20 - What is the difference between file.read() and file.readline() in Python?
#
# ANS - The file.read() method reads the entire contents of a file at once. It is suitable for small files but consumes more memory. The file.readline() method reads one line at a time. It is more memory-efficient. For example, large files are processed using readline().

# %% [markdown]
# Q21 - What is the logging module in Python used for?
#
# ANS - The logging module in Python is used to record messages during program execution. It helps track errors, warnings, and informational messages. The module supports different log levels. Logs can be written to files or displayed on the console. For example, logging.warning() records warning messages.

# %% [markdown]
# Q22 - What is the os module in Python used for in file handling?
#
# ANS - The os module provides functions to interact with the operating system. It allows file creation, deletion, and directory management. The module helps handle file paths and environment variables. It is commonly used in file handling tasks. For example, os.remove() deletes a file.

# %% [markdown]
# Q23- What are the challenges associated with memory management in Python?
#
# ANS -Memory management in Python faces challenges such as circular references and high memory usage. Large objects can consume significant memory. Garbage collection may not occur immediately. These issues can affect performance. For example, large lists can increase memory consumption.

# %% [markdown]
# Q24 - How do you raise an exception manually in Python?
#
# ANS - An exception can be raised manually in Python using the raise keyword. It allows developers to trigger errors intentionally. This is useful for validating inputs. Manual exception raising improves program control. For example, raise ValueError("Invalid input") raises a custom error.

# %% [markdown]
# Q25 - Why is it important to use multithreading in certain applications?
#
# ANS - Multithreading is important because it allows multiple tasks to run concurrently. It improves application responsiveness and performance. Multithreading is especially useful for I/O-bound tasks. It enhances resource utilization. For example, downloading multiple files simultaneously uses multithreading.

# %% [markdown]
# #PRACTICAL QUESTION

# %% [markdown]
# Q1-  How can you open a file for writing in Python and write a string to it?

# %%
f = open("data.txt", "w")
f.write("Hello, Python!")
f.close()

# %% [markdown]
# Q2 -  Write a Python program to read the contents of a file and print each line?

# %%
with open("data.txt", "r") as f:
    for line in f:
        print(line.strip())
# Out:
# Hello, Python!

# %% [markdown]
# Q3 -  How would you handle a case where the file doesn't exist while trying to open it for reading?

# %%
try:
    f = open("missing.txt", "r")
except FileNotFoundError:
    print("File does not exist")
# Out:
# File does not exist

# %% [markdown]
# Q4 - Write a Python script that reads from one file and writes its content to another file?

# %%
with open("source.txt", "r") as src, open("dest.txt", "w") as dst:
    dst.write(src.read())

# %% [markdown]
# Q5 -  How would you catch and handle division by zero error in Python?

# %%
try:
    x = 10 / 0
except ZeroDivisionError:
    print("Cannot divide by zero")

# %% [markdown]
# Q6 - Write a Python program that logs an error message to a log file when a division by zero exception occurs?

# %%
import logging

logging.basicConfig(filename="error.log", level=logging.ERROR)

try:
    x = 10 / 0
except ZeroDivisionError:
    logging.error("Division by zero occurred")

# %% [markdown]
# Q7-  How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging modulE?

# %%
import logging

logging.basicConfig(level=logging.INFO)

logging.info("Program started")
logging.warning("Low memory")
logging.error("An error occurred")

# %% [markdown]
# Q8 - Write a program to handle a file opening error using exception handling?

# %%
try:
    f = open("test.txt", "r")
except IOError:
    print("Error opening file")

# %% [markdown]
# Q9 -  How can you read a file line by line and store its content in a list in Python?

# %%
with open("data.txt", "r") as f:
    lines = f.readlines()

# %% [markdown]
# Q10 - How can you append data to an existing file in Python?

# %%
with open("data.txt", "a") as f:
    f.write("\nNew line added")

# %% [markdown]
# Q11 - Write a Python program that uses a try-except block to handle an error when attempting to access a
# dictionary key that doesn't exist?

# %%
data = {"a": 1}

try:
    print(data["b"])
except KeyError:
    print("Key not found")

# %% [markdown]
# Q12 - Write a program that demonstrates using multiple except blocks to handle different types of exceptions?

# %%
try:
    x = int("abc")
    y = 10 / 0
except ValueError:
    print("Value error")
except ZeroDivisionError:
    print("Division error")

# %% [markdown]
# Q13 - How would you check if a file exists before attempting to read it in Python?

# %%
import os

if os.path.exists("data.txt"):
    print("File exists")

# %% [markdown]
# Q14 - Write a program that uses the logging module to log both informational and error messages?

# %%
import logging

logging.basicConfig(filename="app.log", level=logging.INFO)

logging.info("Application started")
logging.error("Unexpected error")

# %% [markdown]
# Q15 -  Write a Python program that prints the content of a file and handles the case when the file is empty?

# %%
with open("data.txt", "r") as f:
    content = f.read()
    if content:
        print(content)
    else:
        print("File is empty")

# %% [markdown]
# Q16 - Demonstrate how to use memory profiling to check the memory usage of a small program?

# %%
from memory_profiler import profile

@profile
def demo():
    a = [i for i in range(10000)]

demo()

# %% [markdown]
# Q17 -  Write a Python program to create and write a list of numbers to a file, one number per line?

# %%
nums = [1, 2, 3, 4, 5]

with open("numbers.txt", "w") as f:
    for n in nums:
        f.write(str(n) + "\n")

# %% [markdown]
# Q18 - How would you implement a basic logging setup that logs to a file with rotation after 1MB?

# %%
from logging.handlers import RotatingFileHandler
import logging

handler = RotatingFileHandler("app.log", maxBytes=1_000_000, backupCount=3)
logging.basicConfig(handlers=[handler], level=logging.INFO)

# %% [markdown]
# Q19 - Write a program that handles both IndexError and KeyError using a try-except block?

# %%
try:
    lst = [1, 2]
    d = {"a": 10}
    print(lst[5])
    print(d["b"])
except (IndexError, KeyError) as e:
    print("Error:", e)

# %% [markdown]
# Q20 - How would you open a file and read its contents using a context manager in Python?

# %%
with open("data.txt", "r") as f:
    print(f.read())

# %% [markdown]
# Q21 - Write a Python program that reads a file and prints the number of occurrences of a specific word

# %%
with open("data.txt", "r") as f:
    text = f.read()
    print(text.count("Python"))

# %% [markdown]
# Q22 - How can you check if a file is empty before attempting to read its contents?

# %%
import os

if os.path.getsize("data.txt") == 0:
    print("File is empty")

# %% [markdown]
# Q23 -  Write a Python program that writes to a log file when an error occurs during file handling.

# %%
import logging

logging.basicConfig(filename="file_error.log", level=logging.ERROR)

try:
    open("missing.txt", "r")
except FileNotFoundError:
    logging.error("File handling error occurred")
