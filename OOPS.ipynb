# %% [markdown]
# # ASSIGNMENT - OOPs
# # THEORY QUESTION

# %% [markdown]
# Q1 - What is Object-Oriented Programming (OOP)?
#
# ANS - Object-Oriented Programming is a programming paradigm based on objects, which combine data (attributes) and methods (functions).
#
# Key principles: Encapsulation, Abstraction, Inheritance, Polymorphism.

# %% [markdown]
# Q2 - What is a class in OOP?
#
# ANS - A class is a blueprint or template used to create objects.
# It defines the data members (attributes) and member functions (methods) that the objects created from it will have.
#
# Key Points:
#
# A class does not occupy memory until an object is created.
#
# It represents a logical entity.

# %% [markdown]
# Q3 - What is the difference between abstraction and encapsulation?
#
# ANS - Abstraction focuses on hiding the internal implementation details and showing only the essential features of an object to the user. It answers the question what an object does rather than how it does it, and in Python it is commonly achieved using abstract classes and interfaces. On the other hand, encapsulation is concerned with binding data and methods together into a single unit and restricting direct access to some of the object’s components. It answers the question how data is protected, and in Python it is achieved using classes and access modifiers like private variables (using double underscores). In short, abstraction hides complexity, while encapsulation provides data security and controlled access.

# %% [markdown]
# Q4 -  What are dunder methods in Python?
#
# ANS - Dunder methods in Python (short for double underscore methods) are special methods whose names begin and end with double underscores (__). They are also called magic methods because Python automatically calls them to perform specific operations, allowing custom objects to behave like built-in data types.
#
# These methods are used to define how objects behave with operations such as object creation, string representation, arithmetic operations, and comparisons. For example, the __init__ method is called automatically when an object is created to initialize its data, and the __str__ method defines how an object is displayed when printed.

# %% [markdown]
# Q5 - Explain the concept of inheritance in OOP ?
#
# ANS - Inheritance is a fundamental concept of Object-Oriented Programming (OOP) that allows a new class (called the child or derived class) to acquire the properties and behaviors of an existing class (called the parent or base class). By using inheritance, code reusability is achieved because the child class can use the attributes and methods of the parent class without rewriting them. It also supports hierarchical classification and makes programs easier to maintain and extend. In OOP, inheritance represents an “is-a” relationship between classes.

# %% [markdown]
# Q6 - What is polymorphism in OOP?
#
# ANS - Polymorphism in Object-Oriented Programming (OOP) is the concept where a single function, method, or operator can take multiple forms depending on the context in which it is used. The word polymorphism means “many forms”. It allows the same interface or method name to perform different behaviors for different objects, making programs more flexible and scalable. Polymorphism is commonly achieved through method overriding, method overloading, and operator overloading.

# %% [markdown]
# Q7 - How is encapsulation achieved in Python ?
#
# ANS - Encapsulation in Python is achieved by wrapping data (variables) and methods into a single unit (class) and restricting direct access to data members. This is done using private variables, which are declared by prefixing the variable name with double underscores (__). Encapsulation helps in data security, controlled access, and maintainability of code.

# %% [markdown]
# Q9 - What is a constructor in Python ?
#
# ANS - A constructor is a special method in Python named __init__() that is automatically called when an object is created. It is used to initialize the data members of a class. Constructors help ensure that objects start in a valid state.

# %% [markdown]
# Q10 - What are class and static methods in Python ?
#
# ANS - A class method works with class variables and takes cls as its first parameter. It can modify class-level data. A static method does not use instance (self) or class (cls) variables and is mainly used for utility functions related to the class

# %% [markdown]
# Q11 -  What is method overloading in Python?
#
# ANS - Method overloading means defining multiple methods with the same name but different parameters. Python does not support traditional method overloading, but it can be achieved using default arguments or variable-length arguments. This provides flexibility in method usage.

# %% [markdown]
# Q12 - What is method overriding in OOP ?
#
# ANS - Method overriding occurs when a child class provides its own implementation of a method already defined in the parent class. It supports runtime polymorphism and allows the child class to change or extend parent behavior.

# %% [markdown]
# Q13 - What is a property decorator in Python ?
#
# ANS - The @property decorator in Python is used to access a method like an attribute. It allows controlled access to private variables and helps in implementing encapsulation. Using @property, we can change the internal implementation without affecting how the attribute is accessed.

# %% [markdown]
# Q14 -  Why is polymorphism important in OOP?
#
# ANS- Polymorphism is important in OOP because it allows one interface to be used for different data types or objects. It improves code flexibility, reusability, and maintainability. Polymorphism also supports dynamic method binding, making programs easier to extend.

# %% [markdown]
# Q15 - What is an abstract class in Python ?
#
# ANS - An abstract class is a class that cannot be instantiated and is used to define a common structure for its child classes. It contains abstract methods that must be implemented by derived classes. Abstract classes are created using the abc module.

# %% [markdown]
# Q 16 - What are the advantages of OOP?
#
# ANS - The advantages of Object-Oriented Programming include code reusability, modularity, data security, and easy maintenance. OOP makes programs more organized by modeling real-world entities as objects. It also supports scalability and reduces development time

# %% [markdown]
# Q17  - Difference between class variable and instance variable ?
#
#  ANS - A class variable is shared by all objects of a class, while an instance variable is unique to each object. Class variables are defined outside methods, whereas instance variables are defined inside the constructo

# %% [markdown]
# Q18 - What is multiple inheritance in Python?
#
# ANS - Multiple inheritance is a feature in Python where a class can inherit from more than one parent class. It allows a child class to access attributes and methods of multiple base classes. Python uses Method Resolution Order (MRO) to handle ambiguity.

# %% [markdown]
# Q19 - Purpose of __str__ and __repr__ methods in Python?
#
# ANS - The __str__ method returns a readable string representation of an object, mainly for users, while __repr__ returns an official representation useful for debugging. Both methods improve object readability

# %% [markdown]
# Q20 - Significance of the super() function in Python ?
#
# ANS - The super() function is used to call methods of the parent class from a child class. It helps in method overriding, avoids code duplication, and supports multiple inheritancE

# %% [markdown]
# Q21 - Significance of the __del__ method in Python ?
#
# ANS - The __del__ method is a destructor that is called when an object is deleted or garbage collected. It is mainly used to release resources such as files or database connections.

# %% [markdown]
# Q22 - Difference between @staticmethod and @classmethod ?
#
# ANS - A static method does not access class or instance data and is used for utility functions, whereas a class method works with class variables and takes cls as a parameter.

# %% [markdown]
# Q23 -How does polymorphism work in Python with inheritancE?
#
# ANS - In Python, polymorphism with inheritance works through method overriding, where a child class provides a different implementation of a method defined in the parent class. The method call is resolved at runtime, enabling dynamic behavior.

# %% [markdown]
# Q24 - What is Method Chaining in Python OOP?
#
# ANS - Method chaining is a technique in Python OOP where multiple methods are called on the same object in a single statement. This is achieved by having each method return the object itself (self). Method chaining improves code readability, reduces repetition, and allows a fluent programming style.

# %% [markdown]
# Q25 - What is the purpose of the __call__ method in Python?
#
# ANS - The __call__ method allows an object to be called like a function. When an instance is followed by parentheses, Python automatically invokes the __call__ method. It is useful for creating callable objects, such as function-like classes, decorators, and callback implementations.

# %% [markdown]
# # PRACTICAL QUESTION

# %% [markdown]
# Q1 - Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
# that overrides the speak() method to print "Bark!".

# %%
class Animal:
    def speak(self):
        print("Animal makes a sound")

class Dog(Animal):
    def speak(self):
        print("Bark!")

# Example
a = Animal()
d = Dog()
a.speak()
d.speak()
# Out:
# Animal makes a sound
# Bark!

# %% [markdown]
# Q2 - Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
# from it and implement the area() method in both.

# %%
from abc import ABC, abstractmethod
import math

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

class Rectangle(Shape):
    def __init__(self, length, breadth):
        self.length = length
        self.breadth = breadth

    def area(self):
        return self.length * self.breadth

# Example
c = Circle(5)
r = Rectangle(4, 6)
print(c.area())
print(r.area())
# Out:
# 78.53981633974483
# 24

# %% [markdown]
# Q3 -  Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
# and further derive a class ElectricCar that adds a battery attribute

# %%
class Vehicle:
    def __init__(self, vtype):
        self.type = vtype

class Car(Vehicle):
    def __init__(self, vtype, brand):
        super().__init__(vtype)
        self.brand = brand

class ElectricCar(Car):
    def __init__(self, vtype, brand, battery):
        super().__init__(vtype, brand)
        self.battery = battery

# Example
ec = ElectricCar("Four Wheeler", "Tesla", "75 kWh")
print(ec.type, ec.brand, ec.battery)
# Out:
# Four Wheeler Tesla 75 kWh

# %% [markdown]
# Q4 - Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
# Sparrow and Penguin that override the fly() method.

# %%
class Bird:
    def fly(self):
        print("Bird can fly")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high")

class Penguin(Bird):
    def fly(self):
        print("Penguin cannot fly")

# Example
birds = [Sparrow(), Penguin()]
for b in birds:
    b.fly()
# Out:
# Sparrow flies high
# Penguin cannot fly

# %% [markdown]
# Q5 -  Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
# balance and methods to deposit, withdraw, and check balance.

# %%
class BankAccount:
    def __init__(self, balance=0):
        self.__balance = balance  # private attribute

    def deposit(self, amount):
        self.__balance += amount

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
        else:
            print("Insufficient balance")

    def check_balance(self):
        return self.__balance

# Example
acc = BankAccount(1000)
acc.deposit(500)
acc.withdraw(300)
print(acc.check_balance())
# Out:
# 1200

# %% [markdown]
# Q6 -  Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
# and Piano that implement their own version of play().

# %%
class Instrument:
    def play(self):
        print("Instrument is playing")

class Guitar(Instrument):
    def play(self):
        print("Guitar is playing")

class Piano(Instrument):
    def play(self):
        print("Piano is playing")

# Example
i1 = Guitar()
i2 = Piano()
i1.play()
i2.play()
# Out:
# Guitar is playing
# Piano is playing

# %% [markdown]
# Q7 - Create a class MathOperations with a class method add_numbers() to add two numbers and a static
# method subtract_numbers() to subtract two numbers.

# %%
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

# Example
print(MathOperations.add_numbers(10, 5))
print(MathOperations.subtract_numbers(10, 5))
# Out:
# 15
# 5

# %% [markdown]
# Q8 - . Implement a class Person with a class method to count the total number of persons created.

# %%
class Person:
    count = 0

    def __init__(self, name):
        self.name = name
        Person.count += 1

    @classmethod
    def total_persons(cls):
        return cls.count

# Example
p1 = Person("Alice")
p2 = Person("Bob")
p3 = Person("Charlie")
print(Person.total_persons())
# Out:
# 3

# %% [markdown]
# Q9 - Write a class Fraction with attributes numerator and denominator. Override the str method to display the
# fraction as "numerator/denominator".

# %%
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# Example
f = Fraction(3, 4)
print(f)
# Out:
# 3/4

# %% [markdown]
# Q10 - Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
# vectors.

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"

# Example
v1 = Vector(2, 3)
v2 = Vector(4, 5)
print(v1 + v2)
# Out:
# (6, 8)

# %% [markdown]
# Q11 -  Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
# {name} and I am {age} years old."

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# Example
p = Person("Alice", 20)
p.greet()
# Out:
# Hello, my name is Alice and I am 20 years old.

# %% [markdown]
# Q12 - Implement a class Student with attributes name and grades. Create a method average_grade() to compute
# the average of the grades

# %%
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        return sum(self.grades) / len(self.grades)

# Example
s = Student("John", [80, 90, 85])
print(s.average_grade())
# Out:
# 85.0

# %% [markdown]
# Q13 - Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
# area.

# %%
class Rectangle:
    def set_dimensions(self, length, breadth):
        self.length = length
        self.breadth = breadth

    def area(self):
        return self.length * self.breadth

# Example
r = Rectangle()
r.set_dimensions(5, 4)
print(r.area())
# Out:
# 20

# %% [markdown]
# Q14 - Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
# and hourly rate. Create a derived class Manager that adds a bonus to the salary.

# %%
class Employee:
    def calculate_salary(self, hours, rate):
        return hours * rate

class Manager(Employee):
    def calculate_salary(self, hours, rate, bonus):
        return super().calculate_salary(hours, rate) + bonus

# Example
m = Manager()
print(m.calculate_salary(40, 500, 5000))
# Out:
# 25000

# %% [markdown]
# Q15 - Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
# calculates the total price of the product.

# %%
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

# Example
p = Product("Laptop", 50000, 2)
print(p.total_price())
# Out:
# 100000

# %% [markdown]
# Q16 - Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
# implement the sound() method.

# %%
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        print("Moo")

class Sheep(Animal):
    def sound(self):
        print("Baa")

# Example
a1 = Cow()
a2 = Sheep()
a1.sound()
a2.sound()
# Out:
# Moo
# Baa

# %% [markdown]
# Q17 - Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
# returns a formatted string with the book's details.

# %%
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"Title: {self.title}, Author: {self.author}, Year: {self.year_published}"

# Example
b = Book("Python Basics", "John Doe", 2023)
print(b.get_book_info())
# Out:
# Title: Python Basics, Author: John Doe, Year: 2023

# %% [markdown]
# Q18 - Create a class House with attributes address and price. Create a derived class Mansion that adds an
# attribute number_of_rooms

# %%
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

# Example
m = Mansion("New Delhi", 50000000, 10)
print(m.address, m.price, m.number_of_rooms)
# Out:
# New Delhi 50000000 10
